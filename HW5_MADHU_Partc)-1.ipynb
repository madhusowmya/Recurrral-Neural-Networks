# %% [markdown]
# 1.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/HW5/airline-passengers.csv')
data
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
data['Month'] = pd.to_datetime(data['Month'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    datetime64[ns]
#  1   Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
data.set_index('Month', inplace=True)

# %%
data
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %% [markdown]
# Fix the random number seed to 0 in numpy for reproducibility.

# %%
np.random.seed(0)

# %% [markdown]
# Convert the integer values in the data to ﬂoating point values, which are more suitable for modeling with a neural network.

# %%
data['Passengers'] = data['Passengers'].astype(float)

# %%
data['Passengers']
# Out:
# Month
# 1949-01-01    112.0
# 1949-02-01    118.0
# 1949-03-01    132.0
# 1949-04-01    129.0
# 1949-05-01    121.0
#               ...
# 1960-08-01    606.0
# 1960-09-01    508.0
# 1960-10-01    461.0
# 1960-11-01    390.0
# 1960-12-01    432.0
# Name: Passengers, Length: 144, dtype: float64

# %% [markdown]
#  Normalize the data to range (0,1) since LSTMs are sensitive to the scale of the input data, speciﬁcally when the sigmoid or tanh activation functions are used. You can use the MinMaxScaler function in sklearn.

# %%
#data_Scaling
data['Passengers']
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
data=scaler.fit_transform(data)

# %%
data
# Out:
# array([[0.01544402],
#        [0.02702703],
#        [0.05405405],
#        [0.04826255],
#        [0.03281853],
#        [0.05984556],
#        [0.08494208],
#        [0.08494208],
#        [0.06177606],
#        [0.02895753],
#        [0.        ],
#        [0.02702703],
#        [0.02123552],
#        [0.04247104],
#        [0.07142857],
#        [0.05984556],
#        [0.04054054],
#        [0.08687259],
#        [0.12741313],
#        [0.12741313],
#        [0.1042471 ],
#        [0.05598456],
#        [0.01930502],
#        [0.06949807],
#        [0.07915058],
#        [0.08880309],
#        [0.14285714],
#        [0.11389961],
#        [0.13127413],
#        [0.14285714],
#        [0.18339768],
#        [0.18339768],
#        [0.15444015],
#        [0.11196911],
#        [0.08108108],
#        [0.11969112],
#        [0.12934363],
#        [0.14671815],
#        [0.17181467],
#        [0.14864865],
#        [0.15250965],
#        [0.22007722],
#        [0.24324324],
#        [0.26640927],
#        [0.2027027 ],
#        [0.16795367],
#        [0.13127413],
#        [0.17374517],
#        [0.17760618],
#        [0.17760618],
#        [0.25482625],
#        [0.25289575],
#        [0.24131274],
#        [0.26833977],
#        [0.30888031],
#        [0.32432432],
#        [0.25675676],
#        [0.20656371],
#        [0.14671815],
#        [0.18725869],
#        [0.19305019],
#        [0.16216216],
#        [0.25289575],
#        [0.23745174],
#        [0.25096525],
#        [0.30888031],
#        [0.38223938],
#        [0.36486486],
#        [0.2992278 ],
#        [0.24131274],
#        [0.19111969],
#        [0.24131274],
#        [0.26640927],
#        [0.24903475],
#        [0.31467181],
#        [0.31853282],
#        [0.32046332],
#        [0.40733591],
#        [0.5019305 ],
#        [0.46911197],
#        [0.4015444 ],
#        [0.32818533],
#        [0.25675676],
#        [0.33590734],
#        [0.34749035],
#        [0.33397683],
#        [0.41119691],
#        [0.4034749 ],
#        [0.41312741],
#        [0.52123552],
#        [0.5965251 ],
#        [0.58108108],
#        [0.48455598],
#        [0.38996139],
#        [0.32239382],
#        [0.38996139],
#        [0.40733591],
#        [0.38030888],
#        [0.48648649],
#        [0.47104247],
#        [0.48455598],
#        [0.61389961],
#        [0.6969112 ],
#        [0.7007722 ],
#        [0.57915058],
#        [0.46911197],
#        [0.38803089],
#        [0.44787645],
#        [0.45559846],
#        [0.41312741],
#        [0.4980695 ],
#        [0.47104247],
#        [0.5       ],
#        [0.63899614],
#        [0.74710425],
#        [0.77413127],
#        [0.57915058],
#        [0.49227799],
#        [0.3976834 ],
#        [0.44980695],
#        [0.49420849],
#        [0.45945946],
#        [0.58301158],
#        [0.56370656],
#        [0.61003861],
#        [0.71042471],
#        [0.85714286],
#        [0.87837838],
#        [0.69305019],
#        [0.58494208],
#        [0.4980695 ],
#        [0.58108108],
#        [0.6042471 ],
#        [0.55405405],
#        [0.60810811],
#        [0.68918919],
#        [0.71042471],
#        [0.83204633],
#        [1.        ],
#        [0.96911197],
#        [0.77992278],
#        [0.68918919],
#        [0.55212355],
#        [0.63320463]])

# %% [markdown]
# Split the ﬁrst 67% of the data as training data and the remaining 33% as testing data.

# %%
#Creating train and test partition
train = int(len(data)*0.67)
test = len(data)-train

train

test

train_data,test_data=data[0:train,:],data[train:len(data),:1]

# %% [markdown]
# Obtain the two-column input-output dataset to be used in LSTM, where the ﬁrst column is the input (number of passengers in the current month) for each instance (i.e., each row), and the second column is the output (number of passengers next month). In this dataset, the values in the ﬁrst column will be the same as the values in the second column of previous row.

# %%
# converting an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# %% [markdown]
# Reshape the input data to be in the [samples, time steps, features] format, which LSTM network expects. The time step will be 1 with this dataset since each monthly sample represents a unit time step. You can use the
# 1
# reshape function in numpy with (Xtrain.shape[0], 1, Xtrain.shape[1]) as the new size, where Xtrain is the training input data. Apply the same reshaping to the test data Xtest.

# %%
# reshape into X=t and Y=t+1
time_step = 1
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
y_train
# Out:
# array([0.02702703, 0.05405405, 0.04826255, 0.03281853, 0.05984556,
#        0.08494208, 0.08494208, 0.06177606, 0.02895753, 0.        ,
#        0.02702703, 0.02123552, 0.04247104, 0.07142857, 0.05984556,
#        0.04054054, 0.08687259, 0.12741313, 0.12741313, 0.1042471 ,
#        0.05598456, 0.01930502, 0.06949807, 0.07915058, 0.08880309,
#        0.14285714, 0.11389961, 0.13127413, 0.14285714, 0.18339768,
#        0.18339768, 0.15444015, 0.11196911, 0.08108108, 0.11969112,
#        0.12934363, 0.14671815, 0.17181467, 0.14864865, 0.15250965,
#        0.22007722, 0.24324324, 0.26640927, 0.2027027 , 0.16795367,
#        0.13127413, 0.17374517, 0.17760618, 0.17760618, 0.25482625,
#        0.25289575, 0.24131274, 0.26833977, 0.30888031, 0.32432432,
#        0.25675676, 0.20656371, 0.14671815, 0.18725869, 0.19305019,
#        0.16216216, 0.25289575, 0.23745174, 0.25096525, 0.30888031,
#        0.38223938, 0.36486486, 0.2992278 , 0.24131274, 0.19111969,
#        0.24131274, 0.26640927, 0.24903475, 0.31467181, 0.31853282,
#        0.32046332, 0.40733591, 0.5019305 , 0.46911197, 0.4015444 ,
#        0.32818533, 0.25675676, 0.33590734, 0.34749035, 0.33397683,
#        0.41119691, 0.4034749 , 0.41312741, 0.52123552, 0.5965251 ,
#        0.58108108, 0.48455598, 0.38996139, 0.32239382])

# %%
X_train
# Out:
# array([[0.01544402],
#        [0.02702703],
#        [0.05405405],
#        [0.04826255],
#        [0.03281853],
#        [0.05984556],
#        [0.08494208],
#        [0.08494208],
#        [0.06177606],
#        [0.02895753],
#        [0.        ],
#        [0.02702703],
#        [0.02123552],
#        [0.04247104],
#        [0.07142857],
#        [0.05984556],
#        [0.04054054],
#        [0.08687259],
#        [0.12741313],
#        [0.12741313],
#        [0.1042471 ],
#        [0.05598456],
#        [0.01930502],
#        [0.06949807],
#        [0.07915058],
#        [0.08880309],
#        [0.14285714],
#        [0.11389961],
#        [0.13127413],
#        [0.14285714],
#        [0.18339768],
#        [0.18339768],
#        [0.15444015],
#        [0.11196911],
#        [0.08108108],
#        [0.11969112],
#        [0.12934363],
#        [0.14671815],
#        [0.17181467],
#        [0.14864865],
#        [0.15250965],
#        [0.22007722],
#        [0.24324324],
#        [0.26640927],
#        [0.2027027 ],
#        [0.16795367],
#        [0.13127413],
#        [0.17374517],
#        [0.17760618],
#        [0.17760618],
#        [0.25482625],
#        [0.25289575],
#        [0.24131274],
#        [0.26833977],
#        [0.30888031],
#        [0.32432432],
#        [0.25675676],
#        [0.20656371],
#        [0.14671815],
#        [0.18725869],
#        [0.19305019],
#        [0.16216216],
#        [0.25289575],
#        [0.23745174],
#        [0.25096525],
#        [0.30888031],
#        [0.38223938],
#        [0.36486486],
#        [0.2992278 ],
#        [0.24131274],
#        [0.19111969],
#        [0.24131274],
#        [0.26640927],
#        [0.24903475],
#        [0.31467181],
#        [0.31853282],
#        [0.32046332],
#        [0.40733591],
#        [0.5019305 ],
#        [0.46911197],
#        [0.4015444 ],
#        [0.32818533],
#        [0.25675676],
#        [0.33590734],
#        [0.34749035],
#        [0.33397683],
#        [0.41119691],
#        [0.4034749 ],
#        [0.41312741],
#        [0.52123552],
#        [0.5965251 ],
#        [0.58108108],
#        [0.48455598],
#        [0.38996139]])

# %%
X_train.shape, y_train.shape
# Out:
# ((94, 1), (94,))

# %%
# reshape input to be [sample, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1] )

X_train.shape
# Out:
# (94, 1, 1)

# %%
y_train.shape
# Out:
# (94,)

# %% [markdown]
# Build the LSTM network with a hidden layer of 4 neurons, and an output layer with a single neuron. Use sigmoid activation function in the hidden layer, 100 epochs, batch size of 1, “adam” optimizer, and mean-squarederror loss

# %%
import tensorflow 
from tensorflow.keras.models import Sequential
from tensorflow.compat.v1.keras.layers import Dense,CuDNNLSTM, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import math 


model=Sequential()
#model.add(LSTM(4, input_dim=1))
model.add(LSTM(50,return_sequences=True,input_shape=(1,1)))
model.add(LSTM(4))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=1,verbose=1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0348 - val_loss: 0.1645
# Epoch 2/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0146 - val_loss: 0.1093
# Epoch 3/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.0858
# Epoch 4/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0091 - val_loss: 0.0470
# Epoch 5/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0371
# Epoch 6/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0210
# Epoch 7/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0098
# Epoch 8/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0096
# Epoch 9/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0098
# Epoch 10/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0110
# Epoch 11/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0092
# Epoch 12/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0099
# Epoch 13/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0092
# Epoch 14/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0093
# Epoch 15/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0093
# Epoch 16/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0092
# Epoch 17/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0088
# Epoch 18/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0089
# Epoch 19/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0087
# Epoch 20/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0092
# Epoch 21/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0086
# Epoch 22/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0084
# Epoch 23/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0084
# Epoch 24/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0083
# Epoch 25/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0088
# Epoch 26/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0082
# Epoch 27/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0083
# Epoch 28/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0101
# Epoch 29/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0100
# Epoch 30/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0088
# Epoch 31/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0089
# Epoch 32/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0081
# Epoch 33/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0100
# Epoch 34/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0083
# Epoch 35/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0088
# Epoch 36/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 37/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0101
# Epoch 38/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0092
# Epoch 39/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0110
# Epoch 40/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0090
# Epoch 41/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0089
# Epoch 42/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0084
# Epoch 43/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0097
# Epoch 44/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0090
# Epoch 45/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0081
# Epoch 46/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0086
# Epoch 47/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0081
# Epoch 48/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0092
# Epoch 49/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0102
# Epoch 50/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0139
# Epoch 51/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0122
# Epoch 52/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0117
# Epoch 53/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0103
# Epoch 54/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0113
# Epoch 55/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0128
# Epoch 56/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0104
# Epoch 57/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0090
# Epoch 58/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0108
# Epoch 59/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0090
# Epoch 60/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0116
# Epoch 61/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0116
# Epoch 62/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0127
# Epoch 63/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0092
# Epoch 64/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0116
# Epoch 65/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0127
# Epoch 66/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0094
# Epoch 67/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0087
# Epoch 68/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0105
# Epoch 69/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 70/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0102
# Epoch 71/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0116
# Epoch 72/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0146
# Epoch 73/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0107
# Epoch 74/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0114
# Epoch 75/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0118
# Epoch 76/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0101
# Epoch 77/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0102
# Epoch 78/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0131
# Epoch 79/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0100
# Epoch 80/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 81/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0129
# Epoch 82/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0129
# Epoch 83/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0089
# Epoch 84/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0110
# Epoch 85/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0101
# Epoch 86/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0121
# Epoch 87/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0133
# Epoch 88/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0103
# Epoch 89/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0104
# Epoch 90/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0111
# Epoch 91/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0132
# Epoch 92/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0102
# Epoch 93/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0105
# Epoch 94/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0117
# Epoch 95/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0117
# Epoch 96/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0155
# Epoch 97/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0140
# Epoch 98/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0132
# Epoch 99/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0136
# Epoch 100/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0141

# %%
X_train.shape, y_train.shape
# Out:
# ((94, 1, 1), (94,))

# %% [markdown]
#  Predict the next month’s number of passengers and invert the predictions using the “inverse-transform” attribute of MinMaxScaler to go back to the original unit (thousands of passengers per month).

# %%
#Model Prediction
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
#Transforming data back to original form
train_predict=scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform([y_train])
test_predict=scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# %% [markdown]
# Calculate and print the root-mean-squared-error (RMSE) in training and test data.

# %%
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[0], train_predict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], test_predict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 23.89 RMSE
# Test Score: 61.56 RMSE

# %% [markdown]
#  Finally, align and plot the actual and predicted values for the entire dataset including training and testing

# %%
look_back = 1
# shift train predictions for plotting
trainPredictPlot = np.empty_like(data)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(data)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(data)-1, :] = test_predict
# plot baseline and predictions
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.title("Passengers Travelled")
plt.plot(scaler.inverse_transform(data))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
